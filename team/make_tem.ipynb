# %%
# %pip install requests pillow
# Out:
# Collecting requests
#   Using cached requests-2.32.3-py3-none-any.whl (64 kB)
# Collecting pillow
#   Downloading pillow-10.4.0-cp310-cp310-win_amd64.whl (2.6 MB)
#      ---------------------------------------- 0.0/2.6 MB ? eta -:--:--
#      ---------------------------------------- 0.0/2.6 MB ? eta -:--:--
#      - -------------------------------------- 0.1/2.6 MB 1.2 MB/s eta 0:00:03
#      --- ------------------------------------ 0.2/2.6 MB 1.6 MB/s eta 0:00:02
#      ---- ----------------------------------- 0.3/2.6 MB 1.7 MB/s eta 0:00:02
#      ------ --------------------------------- 0.4/2.6 MB 1.7 MB/s eta 0:00:02
#      ------- -------------------------------- 0.5/2.6 MB 1.8 MB/s eta 0:00:02
#      --------- ------------------------------ 0.6/2.6 MB 1.8 MB/s eta 0:00:02
#      ---------- ----------------------------- 0.7/2.6 MB 1.8 MB/s eta 0:00:02
#      ------------ --------------------------- 0.8/2.6 MB 1.9 MB/s eta 0:00:01
#      ------------- -------------------------- 0.9/2.6 MB 1.8 MB/s eta 0:00:01
#      --------------- ------------------------ 1.0/2.6 MB 1.8 MB/s eta 0:00:01
#      ---------------- ----------------------- 1.0/2.6 MB 1.9 MB/s eta 0:00:01
#      ---------------- ----------------------- 1.1/2.6 MB 1.8 MB/s eta 0:00:01
#      ----------------- ---------------------- 1.1/2.6 MB 1.7 MB/s eta 0:00:01
#      ------------------ --------------------- 1.2/2.6 MB 1.7 MB/s eta 0:00:01
#      -------------------- ------------------- 1.3/2.6 MB 1.7 MB/s eta 0:00:01
#      --------------------- ------------------ 1.4/2.6 MB 1.7 MB/s eta 0:00:01
#      ----------------------- ---------------- 1.5/2.6 MB 1.8 MB/s eta 0:00:01
#      ------------------------ --------------- 1.6/2.6 MB 1.8 MB/s eta 0:00:01
#      -------------------------- ------------- 1.7/2.6 MB 1.8 MB/s eta 0:00:01
#      --------------------------- ------------ 1.8/2.6 MB 1.8 MB/s eta 0:00:01
#      ----------------------------- ---------- 1.9/2.6 MB 1.8 MB/s eta 0:00:01
#      -------------------------------- ------- 2.0/2.6 MB 1.9 MB/s eta 0:00:01
#      ---------------------------------- ----- 2.2/2.6 MB 2.0 MB/s eta 0:00:01
#      ----------------------------------- ---- 2.3/2.6 MB 2.0 MB/s eta 0:00:01
#      ------------------------------------- -- 2.4/2.6 MB 1.9 MB/s eta 0:00:01
#      -------------------------------------- - 2.5/2.6 MB 2.0 MB/s eta 0:00:01
#      ---------------------------------------  2.5/2.6 MB 2.0 MB/s eta 0:00:01
#      ---------------------------------------- 2.6/2.6 MB 1.9 MB/s eta 0:00:00
# Collecting urllib3<3,>=1.21.1
#   Using cached urllib3-2.2.2-py3-none-any.whl (121 kB)
# Collecting idna<4,>=2.5
#   Using cached idna-3.7-py3-none-any.whl (66 kB)
# Collecting charset-normalizer<4,>=2
#   Using cached charset_normalizer-3.3.2-cp310-cp310-win_amd64.whl (100 kB)
# Collecting certifi>=2017.4.17
#   Using cached certifi-2024.7.4-py3-none-any.whl (162 kB)
# Installing collected packages: urllib3, pillow, idna, charset-normalizer, certifi, requests
# Successfully installed certifi-2024.7.4 charset-normalizer-3.3.2 idna-3.7 pillow-10.4.0 requests-2.32.3 urllib3-2.2.2
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The script normalizer.exe is installed in 'c:\Users\Admin\AppData\Local\Programs\Python\Python310\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#
# [notice] A new release of pip is available: 23.0.1 -> 24.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
team_data = {"Y21":["Ankit Khandelwal", "Chirayush Mohanty", "Sabyasachi Mohanta", "Chandaka Hemanth Kumar","Jayesh Omprakash Lakade", "Anu Pal", "Chitresh Meena"], "Y22":["Saagar K V","Saraswat","Bhavya Garg"], "Y23":["Archil Mogra","Divyansh Asthana", "Avula Ajay", "Aditya Nitin Patil", "Aaditya Raj"],}

# %%
# # form new.json file get the data of people in team_data
# # Format -->   {
#             "_id": "6511820c754f48b77c035294",
#             "a": "Patna, Bihar",
#             "b": "B+",
#             "d": "Design",
#             "g": "M",
#             "h": "HALLXI",
#             "i": "22219261",
#             "n": "Jayant  Kumar",
#             "p": "PhD",
#             "r": "HALLXI",
#             "u": "jayantk22",
#             "s": "Not available",
#             "c": "Not available"
#         }

import os
import requests
new_data = {}

path = "new.json"
import json
with open(path, "r") as file:
    data = json.load(file)
    print(type(data))
    for team in team_data:
        for person in team_data[team]:
            for person_data in data["documents"]:
                # if all the words in person are in person_data["n"]
                if all(word.lower() in person_data["n"].lower() for word in person.split()):
                    print(person_data)
                    roll = person_data["i"]
                    url = f"https://oa.cc.iitk.ac.in/Oa/Jsp/Photo/{roll}_0.jpg"
                    photo = requests.get(url)
                    # photo.raise_for_status()
                    # show fig 
                    # from PIL import Image
                    # import io
                    # img = Image.open(io.BytesIO(photo.content))
                    # img.show()
                    # break
                    # save the image in photos folder and save the person_data in new json file and save the photo path in person_data
                    os.makedirs("photos", exist_ok=True)
                    with open(f"photos/{person}.jpg", "wb") as file:
                        file.write(photo.content)
                    person_data["photo"] = f"photos/{person}.jpg"
                    new_data[person] = person_data
            else:
                print(f"{person} not found in data")
            print("\n\n")
        print("\n")
# Out:
# <class 'dict'>
# {'_id': '6510296708330d3a53d2874f', 'a': 'Ajmer, Rajasthan', 'b': 'B+', 'd': 'Electrical Engineering', 'g': 'M', 'h': 'HALL13', 'i': '210149', 'n': 'Ankit  Khandelwal', 'p': 'BTech', 'r': 'D-403', 'u': 'ankitkh21', 's': '200556', 'c': 'Not available'}
# Ankit Khandelwal not found in data
#
#
#
# {'_id': '6510296708330d3a53d28756', 'a': 'Cuttack, Orissa', 'b': 'O+', 'd': 'Computer Science and Engineering', 'g': 'M', 'h': 'HALL13', 'i': '210289', 'n': 'Chirayush  Mohanty', 'p': 'BTech', 'r': 'A-412', 'u': 'cmohanty21', 's': '200475', 'c': 'Not available'}
# Chirayush Mohanty not found in data
#
#
#
# {'_id': '6510296a08330d3a53d289f1', 'a': 'RAIRANGPUR, Orissa', 'b': 'O+', 'd': 'Statistics and Data Science', 'g': 'M', 'h': 'HALL13', 'i': '210887', 'n': 'Sabyasachi  Mohanta', 'p': 'BS', 'r': 'C-104', 'u': 'smohanta21', 's': '200231', 'c': 'Not available'}
# Sabyasachi Mohanta not found in data
#
#
#
# {'_id': '6510297008330d3a53d290b7', 'a': 'Vizianagaram, A.P.', 'b': 'O+', 'd': 'Computer Science and Engineering', 'g': 'M', 'h': 'HALL13', 'i': '210277', 'n': 'Chandaka Hemanth Kumar', 'p': 'BTech', 'r': 'A-408', 'u': 'chandaka21', 's': '200393', 'c': 'Not available'}
# Chandaka Hemanth Kumar not found in data
#
#
#
# {'_id': '6510296a08330d3a53d28a9f', 'a': 'Akola, Maharashtra', 'b': 'B+', 'd': 'Economics', 'g': 'M', 'h': 'HALL3', 'i': '200475', 'n': 'Jayesh Omprakash Lakade', 'p': 'BS', 'r': 'E-359', 'u': 'jayeshl20', 's': '190461', 'c': ['210687', '210201', '210289', '210388', '210709']}
# Jayesh Omprakash Lakade not found in data
#
#
#
# {'_id': '6510294f08330d3a53d26a0d', 'a': '', 'b': 'Not Available', 'd': 'Photonics Science and Engineering', 'g': 'M', 'h': '', 'i': '21116002', 'n': 'Anupala  Raghu Vilas', 'p': 'MTech', 'r': '', 'u': 'anupalav21', 's': 'Not available', 'c': 'Not available'}
# {'_id': '6510294f08330d3a53d26bf5', 'a': 'Agra, U.P.', 'b': 'AB+', 'd': 'Civil Engineering', 'g': 'M', 'h': 'DAY', 'i': '22103079', 'n': 'Anup Singh Pal', 'p': 'MTech', 'r': '-9999', 'u': 'anupsp22', 's': 'Not available', 'c': 'Not available'}
# {'_id': '6510296708330d3a53d284c1', 'a': 'KANPUR, U.P.', 'b': 'B+', 'd': 'Civil Engineering', 'g': 'F', 'h': 'HALL4', 'i': '200173', 'n': 'Anushka  Pal', 'p': 'BTech', 'r': 'E-303', 'u': 'anushkap20', 's': '190220', 'c': 'Not available'}
# {'_id': '6510296d08330d3a53d29019', 'a': 'Mainpuri, U.P.', 'b': 'O+', 'd': 'Mechanical Engineering', 'g': 'M', 'h': 'HALL13', 'i': '210160', 'n': 'Anu  Pal', 'p': 'BTech', 'r': 'A-109', 'u': 'anupal21', 's': '200915', 'c': 'Not available'}
# Anu Pal not found in data
#
#
#
# {'_id': '6510296708330d3a53d28854', 'a': 'Guna, Madhya Pradesh', 'd': 'Economics', 'g': 'M', 'h': 'HALL13', 'i': '210291', 'n': 'Chitresh  Meena', 'p': 'BS', 'r': 'A-106', 'u': 'cmeena21', 'b': '', 's': '200798', 'c': 'Not available'}
# Chitresh Meena not found in data
#
#
#
#
#
# {'_id': '6510297008330d3a53d29422', 'a': 'Amarapuram, A.P.', 'b': 'O+', 'd': 'Electrical Engineering', 'g': 'M', 'h': 'HALL13', 'i': '220927', 'n': 'Saagar K V', 'p': 'BTech', 'r': 'C-211', 'u': 'saagar22', 's': '210463', 'c': 'Not available'}
# Saagar K V not found in data
#
#
#
# {'_id': '6510294608330d3a53d26014', 'a': 'KUSHINAGAR, U.P.', 'b': 'O+', 'd': 'Chemistry', 'g': 'F', 'h': 'GH', 'i': '19107283', 'n': 'Nandini  Saraswati', 'p': 'PhD', 'r': 'G-304', 'u': 'nandis', 's': 'Not available', 'c': 'Not available'}
# {'_id': '6510294908330d3a53d26203', 'a': 'Mathura, U.P.', 'b': 'Not Available', 'd': 'Computer Science and Engineering', 'g': 'M', 'h': 'HALLX', 'i': '20111073', 'n': 'Yash  Saraswat', 'p': 'MTech', 'r': 'B-438', 'u': 'yash20', 's': 'Not available', 'c': 'Not available'}
# {'_id': '6510295608330d3a53d27393', 'a': '', 'b': 'Not Available', 'd': 'Industrial and Management Engineering', 'g': 'M', 'h': '', 'i': '22125099', 'n': 'Vinayak  Saraswat', 'p': 'MBA', 'r': '', 'u': 'vinayak22', 's': 'Not available', 'c': 'Not available'}
# {'_id': '6510295d08330d3a53d27968', 'a': 'Jaipur, Rajasthan', 'b': 'A+', 'd': 'Physics', 'g': 'F', 'h': 'HALL6', 'i': '161172', 'n': 'Tripti  Saraswat', 'p': 'MSc-PhD(Dual)', 'r': 'GHTA-610', 'u': 'tripti', 's': 'Not available', 'c': 'Not available'}
# {'_id': '6510295d08330d3a53d27a79', 'a': '', 'b': 'Not Available', 'd': 'Industrial and Management Engineering', 'g': 'F', 'h': '', 'i': 'Y7114062', 'n': 'Swati A Saraswat', 'p': 'PhD', 'r': '', 'u': '', 's': 'Not available', 'c': 'Not available'}
# {'_id': '6510296708330d3a53d28766', 'a': 'AGRA, U.P.', 'b': 'B+', 'd': 'Aerospace Engineering', 'g': 'F', 'h': 'GH', 'i': '190708', 'n': 'Rishika  Saraswat', 'p': 'BTech', 'r': 'B-313', 'u': 'rishika', 's': '180237', 'c': 'Not available'}
# {'_id': '6510297408330d3a53d2955e', 'a': 'Saharsa, Bihar', 'b': 'A+', 'd': 'Mechanical Engineering', 'g': 'M', 'h': 'HALL13', 'i': '220974', 'n': 'Saraswat', 'p': 'BTech', 'r': 'C-306', 'u': 'saraswat22', 's': '210058', 'c': 'Not available'}
# Saraswat not found in data
#
#
#
# {'_id': '6510296d08330d3a53d28dc4', 'a': 'JAIPUR, Rajasthan', 'b': 'A+', 'd': 'Computer Science and Engineering', 'g': 'M', 'h': 'HALL3', 'i': '200270', 'n': 'Bhavya  Garg', 'p': 'BTech', 'r': 'D-236', 'u': 'bhavyag20', 's': '190994', 'c': 'Not available'}
# {'_id': '6510297008330d3a53d29157', 'a': 'Meerut, U.P.', 'b': 'A+', 'd': 'Biological Sciences and Bioengineering', 'g': 'M', 'h': 'HALL13', 'i': '220296', 'n': 'Bhavya Garg', 'p': 'BTech', 'r': 'E-409', 'u': 'bhavya22', 's': '210616', 'c': 'Not available'}
# Bhavya Garg not found in data
#
#
#
#
#
# {'_id': '6510297408330d3a53d296e6', 'a': 'Raj, Rajasthan', 'b': 'A+', 'd': 'Chemical Engineering', 'g': 'M', 'h': 'HALL13', 'i': '230185', 'n': 'Archil Mogra', 'p': 'BTech', 'r': 'F-302', 'u': 'archilm23', 's': '220816', 'c': 'Not available'}
# Archil Mogra not found in data
#
#
#
# {'_id': '6510297608330d3a53d29a78', 'a': 'Navi Mumbai, Maharashtra', 'b': 'B+', 'd': 'Earth Science', 'g': 'M', 'h': 'HALL13', 'i': '230380', 'n': 'Divyansh Asthana', 'p': 'BS', 'r': 'D-208', 'u': 'divyansh23', 's': '220807', 'c': 'Not available'}
# Divyansh Asthana not found in data
#
#
#
# {'_id': '6510297608330d3a53d29b90', 'a': 'PEDDAPALLI, TELANGANA', 'b': 'B+', 'd': 'Electrical Engineering', 'g': 'M', 'h': 'HALL13', 'i': '230248', 'n': 'Avula Ajay', 'p': 'BTech', 'r': 'A-409', 'u': 'ajayl23', 's': '220360', 'c': 'Not available'}
# Avula Ajay not found in data
#
#
#
# {'_id': '6510297408330d3a53d296de', 'a': 'NASHIK, Maharashtra', 'b': 'B-', 'd': 'Chemical Engineering', 'g': 'M', 'h': 'HALL13', 'i': '230074', 'n': 'Aditya Nitin Patil', 'p': 'BTech', 'r': 'E-313', 'u': 'adityanp23', 's': '220055', 'c': 'Not available'}
# Aditya Nitin Patil not found in data
#
#
#
# {'_id': '6510297008330d3a53d291ed', 'a': 'Matihani, Other', 'b': 'AB+', 'd': 'Chemistry', 'g': 'M', 'h': 'HALL13', 'i': '220008', 'n': 'Aaditya Raj Yadav', 'p': 'BS', 'r': 'E-213', 'u': 'aadityary22', 's': '210535', 'c': 'Not available'}
# {'_id': '6510297908330d3a53d29ef3', 'a': 'patna, Bihar', 'b': 'O-', 'd': 'Materials Science and Engineering', 'g': 'M', 'h': 'HALL13', 'i': '230005', 'n': 'Aaditya Raj', 'p': 'BTech', 'r': 'C-404', 'u': 'aadityaraj23', 's': '221032', 'c': 'Not available'}
# Aaditya Raj not found in data

# %%
new_data
# Out:
# {'Ankit Khandelwal': {'_id': '6510296708330d3a53d2874f',
#   'a': 'Ajmer, Rajasthan',
#   'b': 'B+',
#   'd': 'Electrical Engineering',
#   'g': 'M',
#   'h': 'HALL13',
#   'i': '210149',
#   'n': 'Ankit  Khandelwal',
#   'p': 'BTech',
#   'r': 'D-403',
#   'u': 'ankitkh21',
#   's': '200556',
#   'c': 'Not available',
#   'photo': 'photos/Ankit Khandelwal.jpg'},
#  'Chirayush Mohanty': {'_id': '6510296708330d3a53d28756',
#   'a': 'Cuttack, Orissa',
#   'b': 'O+',
#   'd': 'Computer Science and Engineering',
#   'g': 'M',
#   'h': 'HALL13',
#   'i': '210289',
#   'n': 'Chirayush  Mohanty',
#   'p': 'BTech',
#   'r': 'A-412',
#   'u': 'cmohanty21',
#   's': '200475',
#   'c': 'Not available',
#   'photo': 'photos/Chirayush Mohanty.jpg'},
#  'Sabyasachi Mohanta': {'_id': '6510296a08330d3a53d289f1',
#   'a': 'RAIRANGPUR, Orissa',
#   'b': 'O+',
#   'd': 'Statistics and Data Science',
#   'g': 'M',
#   'h': 'HALL13',
#   'i': '210887',
#   'n': 'Sabyasachi  Mohanta',
#   'p': 'BS',
#   'r': 'C-104',
#   'u': 'smohanta21',
#   's': '200231',
#   'c': 'Not available',
#   'photo': 'photos/Sabyasachi Mohanta.jpg'},
#  'Chandaka Hemanth Kumar': {'_id': '6510297008330d3a53d290b7',
#   'a': 'Vizianagaram, A.P.',
#   'b': 'O+',
#   'd': 'Computer Science and Engineering',
#   'g': 'M',
#   'h': 'HALL13',
#   'i': '210277',
#   'n': 'Chandaka Hemanth Kumar',
#   'p': 'BTech',
#   'r': 'A-408',
#   'u': 'chandaka21',
#   's': '200393',
#   'c': 'Not available',
#   'photo': 'photos/Chandaka Hemanth Kumar.jpg'},
#  'Anu Pal': {'_id': '6510296d08330d3a53d29019',
#   'a': 'Mainpuri, U.P.',
#   'b': 'O+',
#   'd': 'Mechanical Engineering',
#   'g': 'M',
#   'h': 'HALL13',
#   'i': '210160',
#   'n': 'Anu  Pal',
#   'p': 'BTech',
#   'r': 'A-109',
#   'u': 'anupal21',
#   's': '200915',
#   'c': 'Not available',
#   'photo': 'photos/Anu Pal.jpg'},
#  'Chitresh Meena': {'_id': '6510296708330d3a53d28854',
#   'a': 'Guna, Madhya Pradesh',
#   'd': 'Economics',
#   'g': 'M',
#   'h': 'HALL13',
#   'i': '210291',
#   'n': 'Chitresh  Meena',
#   'p': 'BS',
#   'r': 'A-106',
#   'u': 'cmeena21',
#   'b': '',
#   's': '200798',
#   'c': 'Not available',
#   'photo': 'photos/Chitresh Meena.jpg'},
#  'Saagar K V': {'_id': '6510297008330d3a53d29422',
#   'a': 'Amarapuram, A.P.',
#   'b': 'O+',
#   'd': 'Electrical Engineering',
#   'g': 'M',
#   'h': 'HALL13',
#   'i': '220927',
#   'n': 'Saagar K V',
#   'p': 'BTech',
#   'r': 'C-211',
#   'u': 'saagar22',
#   's': '210463',
#   'c': 'Not available',
#   'photo': 'photos/Saagar K V.jpg'},
#  'Saraswat': {'_id': '6510297408330d3a53d2955e',
#   'a': 'Saharsa, Bihar',
#   'b': 'A+',
#   'd': 'Mechanical Engineering',
#   'g': 'M',
#   'h': 'HALL13',
#   'i': '220974',
#   'n': 'Saraswat',
#   'p': 'BTech',
#   'r': 'C-306',
#   'u': 'saraswat22',
#   's': '210058',
#   'c': 'Not available',
#   'photo': 'photos/Saraswat.jpg'},
#  'Bhavya Garg': {'_id': '6510297008330d3a53d29157',
#   'a': 'Meerut, U.P.',
#   'b': 'A+',
#   'd': 'Biological Sciences and Bioengineering',
#   'g': 'M',
#   'h': 'HALL13',
#   'i': '220296',
#   'n': 'Bhavya Garg',
#   'p': 'BTech',
#   'r': 'E-409',
#   'u': 'bhavya22',
#   's': '210616',
#   'c': 'Not available',
#   'photo': 'photos/Bhavya Garg.jpg'},
#  'Archil Mogra': {'_id': '6510297408330d3a53d296e6',
#   'a': 'Raj, Rajasthan',
#   'b': 'A+',
#   'd': 'Chemical Engineering',
#   'g': 'M',
#   'h': 'HALL13',
#   'i': '230185',
#   'n': 'Archil Mogra',
#   'p': 'BTech',
#   'r': 'F-302',
#   'u': 'archilm23',
#   's': '220816',
#   'c': 'Not available',
#   'photo': 'photos/Archil Mogra.jpg'},
#  'Divyansh Asthana': {'_id': '6510297608330d3a53d29a78',
#   'a': 'Navi Mumbai, Maharashtra',
#   'b': 'B+',
#   'd': 'Earth Science',
#   'g': 'M',
#   'h': 'HALL13',
#   'i': '230380',
#   'n': 'Divyansh Asthana',
#   'p': 'BS',
#   'r': 'D-208',
#   'u': 'divyansh23',
#   's': '220807',
#   'c': 'Not available',
#   'photo': 'photos/Divyansh Asthana.jpg'},
#  'Avula Ajay': {'_id': '6510297608330d3a53d29b90',
#   'a': 'PEDDAPALLI, TELANGANA',
#   'b': 'B+',
#   'd': 'Electrical Engineering',
#   'g': 'M',
#   'h': 'HALL13',
#   'i': '230248',
#   'n': 'Avula Ajay',
#   'p': 'BTech',
#   'r': 'A-409',
#   'u': 'ajayl23',
#   's': '220360',
#   'c': 'Not available',
#   'photo': 'photos/Avula Ajay.jpg'},
#  'Aditya Nitin Patil': {'_id': '6510297408330d3a53d296de',
#   'a': 'NASHIK, Maharashtra',
#   'b': 'B-',
#   'd': 'Chemical Engineering',
#   'g': 'M',
#   'h': 'HALL13',
#   'i': '230074',
#   'n': 'Aditya Nitin Patil',
#   'p': 'BTech',
#   'r': 'E-313',
#   'u': 'adityanp23',
#   's': '220055',
#   'c': 'Not available',
#   'photo': 'photos/Aditya Nitin Patil.jpg'},
#  'Aaditya Raj': {'_id': '6510297908330d3a53d29ef3',
#   'a': 'patna, Bihar',
#   'b': 'O-',
#   'd': 'Materials Science and Engineering',
#   'g': 'M',
#   'h': 'HALL13',
#   'i': '230005',
#   'n': 'Aaditya Raj',
#   'p': 'BTech',
#   'r': 'C-404',
#   'u': 'aadityaraj23',
#   's': '221032',
#   'c': 'Not available',
#   'photo': 'photos/Aaditya Raj.jpg'}}

# %%
# for url get photo and save photo with name as person name in photos folder
import requests
url = f"https://oa.cc.iitk.ac.in/Oa/Jsp/Photo/{person_data["i"]}.jpg"
# Out:
#   Cell In[38], line 3
#     url = f"https://oa.cc.iitk.ac.in/Oa/Jsp/Photo/{person_data["i"]}.jpg"
#                                                                 ^
# SyntaxError: f-string: unmatched '['

# %%
# %pip install beautifulsoup4
# Out:
# Collecting beautifulsoup4
#   Downloading beautifulsoup4-4.12.3-py3-none-any.whl (147 kB)
#      ---------------------------------------- 0.0/147.9 kB ? eta -:--:--
#      -- ------------------------------------- 10.2/147.9 kB ? eta -:--:--
#      --------------------- ----------------- 81.9/147.9 kB 1.1 MB/s eta 0:00:01
#      --------------------------- -------- 112.6/147.9 kB 930.9 kB/s eta 0:00:01
#      ------------------------------------ 147.9/147.9 kB 732.4 kB/s eta 0:00:00
# Collecting soupsieve>1.2
#   Using cached soupsieve-2.5-py3-none-any.whl (36 kB)
# Installing collected packages: soupsieve, beautifulsoup4
# Successfully installed beautifulsoup4-4.12.3 soupsieve-2.5
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.0.1 -> 24.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# html format

# make circle with photo
# name
# program, year, roll number
# email


format = """
                <div class="col-md-4 col-lg-4 col-sm-6 col-10">
                    <div class="single-blog-item sm-mb30 xs-mb30 wow fadeInUp" data-wow-delay="0.3s">
                        <div class="blog-thumb">
                            <a href="#"><img src="team_img\ChitreshMeena.jpg" style="height:35rem;width:35rem" alt=""></a>
                        </div>
                        <div class="blog-details padding30">
                            <h3 class="blog-title font20 mb30">
                                <a href="#">
                                Chitresh Meena  <br /> UG(ECO), Y21 <br /> 210111 </a>
                            </h3>
                            <p class="blog-meta font14 mt20">
                                <a href="#">cmeena21@iitk.ac.in</a>
                            </p>
                        </div>
                    </div>
                </div>
                """
# path is index.html insert the format in the div with class row team-member
from bs4 import BeautifulSoup
with open("team.html", "r") as file:
    soup = BeautifulSoup(file, "html.parser")
    team_member = soup.find("div", class_="row center justify-content-center")
    for person in new_data:
        person_data = new_data[person]
        # person_format = format.replace("ChitreshMeena", person.replace(" ", ""))
        person_format = format.replace("Chitresh Meena", person_data["n"])
        # print(person_format)
        person_format = person_format.replace("UG(ECO), Y21", f"{person_data['p']}({person_data['d']}), Y{person_data['i'][0:2]}")
        person_format = person_format.replace("210111", person_data["i"])
        person_format = person_format.replace("cmeena21@iitk.ac.in", f"{person_data['u']}@iitk.ac.in")
        person_format = person_format.replace("team_img\ChitreshMeena.jpg", person_data["photo"])
        print(person_format)
        # break
        team_member.append(BeautifulSoup(person_format, "html.parser"))
# os.makedirs("team.html", exist_ok=True)
with open("index.html", "w") as file:
    file.write(str(soup))
# Out:
#                 <div class="col-md-4 col-lg-4 col-sm-6 col-10">
#                     <div class="single-blog-item sm-mb30 xs-mb30 wow fadeInUp" data-wow-delay="0.3s">
#                         <div class="blog-thumb">
#                             <a href="#"><img src="photos/Ankit Khandelwal.jpg" style="height:35rem;width:35rem" alt=""></a>
#                         </div>
#                         <div class="blog-details padding30">
#                             <h3 class="blog-title font20 mb30">
#                                 <a href="#">
#                                 Ankit  Khandelwal  <br /> BTech(Electrical Engineering), Y21 <br /> 210149 </a>
#                             </h3>
#                             <p class="blog-meta font14 mt20">
#                                 <a href="#">ankitkh21@iitk.ac.in</a>
#                             </p>
#                         </div>
#                     </div>
#                 </div>
#
#
#                 <div class="col-md-4 col-lg-4 col-sm-6 col-10">
#                     <div class="single-blog-item sm-mb30 xs-mb30 wow fadeInUp" data-wow-delay="0.3s">
#                         <div class="blog-thumb">
#                             <a href="#"><img src="photos/Chirayush Mohanty.jpg" style="height:35rem;width:35rem" alt=""></a>
#                         </div>
#                         <div class="blog-details padding30">
#                             <h3 class="blog-title font20 mb30">
#                                 <a href="#">
#                                 Chirayush  Mohanty  <br /> BTech(Computer Science and Engineering), Y21 <br /> 210289 </a>
#                             </h3>
#                             <p class="blog-meta font14 mt20">
#                                 <a href="#">cmohanty21@iitk.ac.in</a>
#                             </p>
#                         </div>
#                     </div>
#                 </div>
#
#
#                 <div class="col-md-4 col-lg-4 col-sm-6 col-10">
#                     <div class="single-blog-item sm-mb30 xs-mb30 wow fadeInUp" data-wow-delay="0.3s">
#                         <div class="blog-thumb">
#                             <a href="#"><img src="photos/Sabyasachi Mohanta.jpg" style="height:35rem;width:35rem" alt=""></a>
#                         </div>
#                         <div class="blog-details padding30">
#                             <h3 class="blog-title font20 mb30">
#                                 <a href="#">
#                                 Sabyasachi  Mohanta  <br /> BS(Statistics and Data Science), Y21 <br /> 210887 </a>
#                             </h3>
#                             <p class="blog-meta font14 mt20">
#                                 <a href="#">smohanta21@iitk.ac.in</a>
#                             </p>
#                         </div>
#                     </div>
#                 </div>
#
#
#                 <div class="col-md-4 col-lg-4 col-sm-6 col-10">
#                     <div class="single-blog-item sm-mb30 xs-mb30 wow fadeInUp" data-wow-delay="0.3s">
#                         <div class="blog-thumb">
#                             <a href="#"><img src="photos/Chandaka Hemanth Kumar.jpg" style="height:35rem;width:35rem" alt=""></a>
#                         </div>
#                         <div class="blog-details padding30">
#                             <h3 class="blog-title font20 mb30">
#                                 <a href="#">
#                                 Chandaka Hemanth Kumar  <br /> BTech(Computer Science and Engineering), Y21 <br /> 210277 </a>
#                             </h3>
#                             <p class="blog-meta font14 mt20">
#                                 <a href="#">chandaka21@iitk.ac.in</a>
#                             </p>
#                         </div>
#                     </div>
#                 </div>
#
#
#                 <div class="col-md-4 col-lg-4 col-sm-6 col-10">
#                     <div class="single-blog-item sm-mb30 xs-mb30 wow fadeInUp" data-wow-delay="0.3s">
#                         <div class="blog-thumb">
#                             <a href="#"><img src="photos/Jayesh Omprakash Lakade.jpg" style="height:35rem;width:35rem" alt=""></a>
#                         </div>
#                         <div class="blog-details padding30">
#                             <h3 class="blog-title font20 mb30">
#                                 <a href="#">
#                                 Jayesh Omprakash Lakade  <br /> BS(Economics), Y20 <br /> 200475 </a>
#                             </h3>
#                             <p class="blog-meta font14 mt20">
#                                 <a href="#">jayeshl20@iitk.ac.in</a>
#                             </p>
#                         </div>
#                     </div>
#                 </div>
#
#
#                 <div class="col-md-4 col-lg-4 col-sm-6 col-10">
#                     <div class="single-blog-item sm-mb30 xs-mb30 wow fadeInUp" data-wow-delay="0.3s">
#                         <div class="blog-thumb">
#                             <a href="#"><img src="photos/Anu Pal.jpg" style="height:35rem;width:35rem" alt=""></a>
#                         </div>
#                         <div class="blog-details padding30">
#                             <h3 class="blog-title font20 mb30">
#                                 <a href="#">
#                                 Anu  Pal  <br /> BTech(Mechanical Engineering), Y21 <br /> 210160 </a>
#                             </h3>
#                             <p class="blog-meta font14 mt20">
#                                 <a href="#">anupal21@iitk.ac.in</a>
#                             </p>
#                         </div>
#                     </div>
#                 </div>
#
#
#                 <div class="col-md-4 col-lg-4 col-sm-6 col-10">
#                     <div class="single-blog-item sm-mb30 xs-mb30 wow fadeInUp" data-wow-delay="0.3s">
#                         <div class="blog-thumb">
#                             <a href="#"><img src="photos/Chitresh Meena.jpg" style="height:35rem;width:35rem" alt=""></a>
#                         </div>
#                         <div class="blog-details padding30">
#                             <h3 class="blog-title font20 mb30">
#                                 <a href="#">
#                                 Chitresh  Meena  <br /> BS(Economics), Y21 <br /> 210291 </a>
#                             </h3>
#                             <p class="blog-meta font14 mt20">
#                                 <a href="#">cmeena21@iitk.ac.in</a>
#                             </p>
#                         </div>
#                     </div>
#                 </div>
#
#
#                 <div class="col-md-4 col-lg-4 col-sm-6 col-10">
#                     <div class="single-blog-item sm-mb30 xs-mb30 wow fadeInUp" data-wow-delay="0.3s">
#                         <div class="blog-thumb">
#                             <a href="#"><img src="photos/Saagar K V.jpg" style="height:35rem;width:35rem" alt=""></a>
#                         </div>
#                         <div class="blog-details padding30">
#                             <h3 class="blog-title font20 mb30">
#                                 <a href="#">
#                                 Saagar K V  <br /> BTech(Electrical Engineering), Y22 <br /> 220927 </a>
#                             </h3>
#                             <p class="blog-meta font14 mt20">
#                                 <a href="#">saagar22@iitk.ac.in</a>
#                             </p>
#                         </div>
#                     </div>
#                 </div>
#
#
#                 <div class="col-md-4 col-lg-4 col-sm-6 col-10">
#                     <div class="single-blog-item sm-mb30 xs-mb30 wow fadeInUp" data-wow-delay="0.3s">
#                         <div class="blog-thumb">
#                             <a href="#"><img src="photos/Saraswat.jpg" style="height:35rem;width:35rem" alt=""></a>
#                         </div>
#                         <div class="blog-details padding30">
#                             <h3 class="blog-title font20 mb30">
#                                 <a href="#">
#                                 Saraswat  <br /> BTech(Mechanical Engineering), Y22 <br /> 220974 </a>
#                             </h3>
#                             <p class="blog-meta font14 mt20">
#                                 <a href="#">saraswat22@iitk.ac.in</a>
#                             </p>
#                         </div>
#                     </div>
#                 </div>
#
#
#                 <div class="col-md-4 col-lg-4 col-sm-6 col-10">
#                     <div class="single-blog-item sm-mb30 xs-mb30 wow fadeInUp" data-wow-delay="0.3s">
#                         <div class="blog-thumb">
#                             <a href="#"><img src="photos/Bhavya Garg.jpg" style="height:35rem;width:35rem" alt=""></a>
#                         </div>
#                         <div class="blog-details padding30">
#                             <h3 class="blog-title font20 mb30">
#                                 <a href="#">
#                                 Bhavya Garg  <br /> BTech(Biological Sciences and Bioengineering), Y22 <br /> 220296 </a>
#                             </h3>
#                             <p class="blog-meta font14 mt20">
#                                 <a href="#">bhavya22@iitk.ac.in</a>
#                             </p>
#                         </div>
#                     </div>
#                 </div>
#
#
#                 <div class="col-md-4 col-lg-4 col-sm-6 col-10">
#                     <div class="single-blog-item sm-mb30 xs-mb30 wow fadeInUp" data-wow-delay="0.3s">
#                         <div class="blog-thumb">
#                             <a href="#"><img src="photos/Archil Mogra.jpg" style="height:35rem;width:35rem" alt=""></a>
#                         </div>
#                         <div class="blog-details padding30">
#                             <h3 class="blog-title font20 mb30">
#                                 <a href="#">
#                                 Archil Mogra  <br /> BTech(Chemical Engineering), Y23 <br /> 230185 </a>
#                             </h3>
#                             <p class="blog-meta font14 mt20">
#                                 <a href="#">archilm23@iitk.ac.in</a>
#                             </p>
#                         </div>
#                     </div>
#                 </div>
#
#
#                 <div class="col-md-4 col-lg-4 col-sm-6 col-10">
#                     <div class="single-blog-item sm-mb30 xs-mb30 wow fadeInUp" data-wow-delay="0.3s">
#                         <div class="blog-thumb">
#                             <a href="#"><img src="photos/Divyansh Asthana.jpg" style="height:35rem;width:35rem" alt=""></a>
#                         </div>
#                         <div class="blog-details padding30">
#                             <h3 class="blog-title font20 mb30">
#                                 <a href="#">
#                                 Divyansh Asthana  <br /> BS(Earth Science), Y23 <br /> 230380 </a>
#                             </h3>
#                             <p class="blog-meta font14 mt20">
#                                 <a href="#">divyansh23@iitk.ac.in</a>
#                             </p>
#                         </div>
#                     </div>
#                 </div>
#
#
#                 <div class="col-md-4 col-lg-4 col-sm-6 col-10">
#                     <div class="single-blog-item sm-mb30 xs-mb30 wow fadeInUp" data-wow-delay="0.3s">
#                         <div class="blog-thumb">
#                             <a href="#"><img src="photos/Avula Ajay.jpg" style="height:35rem;width:35rem" alt=""></a>
#                         </div>
#                         <div class="blog-details padding30">
#                             <h3 class="blog-title font20 mb30">
#                                 <a href="#">
#                                 Avula Ajay  <br /> BTech(Electrical Engineering), Y23 <br /> 230248 </a>
#                             </h3>
#                             <p class="blog-meta font14 mt20">
#                                 <a href="#">ajayl23@iitk.ac.in</a>
#                             </p>
#                         </div>
#                     </div>
#                 </div>
#
#
#                 <div class="col-md-4 col-lg-4 col-sm-6 col-10">
#                     <div class="single-blog-item sm-mb30 xs-mb30 wow fadeInUp" data-wow-delay="0.3s">
#                         <div class="blog-thumb">
#                             <a href="#"><img src="photos/Aditya Nitin Patil.jpg" style="height:35rem;width:35rem" alt=""></a>
#                         </div>
#                         <div class="blog-details padding30">
#                             <h3 class="blog-title font20 mb30">
#                                 <a href="#">
#                                 Aditya Nitin Patil  <br /> BTech(Chemical Engineering), Y23 <br /> 230074 </a>
#                             </h3>
#                             <p class="blog-meta font14 mt20">
#                                 <a href="#">adityanp23@iitk.ac.in</a>
#                             </p>
#                         </div>
#                     </div>
#                 </div>
#
#
#                 <div class="col-md-4 col-lg-4 col-sm-6 col-10">
#                     <div class="single-blog-item sm-mb30 xs-mb30 wow fadeInUp" data-wow-delay="0.3s">
#                         <div class="blog-thumb">
#                             <a href="#"><img src="photos/Aaditya Raj.jpg" style="height:35rem;width:35rem" alt=""></a>
#                         </div>
#                         <div class="blog-details padding30">
#                             <h3 class="blog-title font20 mb30">
#                                 <a href="#">
#                                 Aaditya Raj  <br /> BTech(Materials Science and Engineering), Y23 <br /> 230005 </a>
#                             </h3>
#                             <p class="blog-meta font14 mt20">
#                                 <a href="#">aadityaraj23@iitk.ac.in</a>
#                             </p>
#                         </div>
#                     </div>
#                 </div>
